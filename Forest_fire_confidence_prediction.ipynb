# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijitguinkatwa/machine-learning-project/blob/main/Forest_fire_confidence_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime as dt

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestRegressor

# %%
forest = pd.read_csv('/content/fire_archive.csv')

forest.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01        56
# 1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01        56
# 2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01        57
# 3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01        57
# 4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01        57
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          48      6.3       297.3   6.6        D     0
# 1     Terra      MODIS          71      6.3       297.3  11.3        D     0
# 2     Terra      MODIS          42      6.3       298.7  23.1        D     0
# 3     Terra      MODIS          33      6.3       296.1   6.5        D     0
# 4     Terra      MODIS          36      6.3       298.8  27.6        D     0

# %%
forest.shape
# Out:
# (36011, 15)

# %%
forest.isnull().sum()
# Out:
# latitude      0
# longitude     0
# brightness    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_t31    0
# frp           0
# daynight      0
# type          0
# dtype: int64

# %%
forest.describe()
# Out:
#            latitude     longitude    brightness          scan         track  \
# count  36011.000000  36011.000000  36011.000000  36011.000000  36011.000000
# mean     -19.100962    138.931446    328.750696      1.620905      1.215281
# std        7.265777      9.261400     18.992808      0.813764      0.247852
# min      -42.762800    114.104300    300.000000      1.000000      1.000000
# 25%      -26.370250    131.072250    316.500000      1.100000      1.000000
# 50%      -15.706500    136.738500    326.400000      1.300000      1.100000
# 75%      -13.343600    147.477500    336.700000      1.900000      1.300000
# max      -10.072600    153.490400    504.400000      4.800000      2.000000
#
#            acq_time    confidence       version    bright_t31           frp  \
# count  36011.000000  36011.000000  3.601100e+04  36011.000000  36011.000000
# mean     600.025798     67.551387  6.300000e+00    301.339138     51.132176
# std      548.369111     23.179946  1.776382e-15      9.724462     92.280112
# min        0.000000      0.000000  6.300000e+00    267.000000      0.000000
# 25%      205.000000     52.000000  6.300000e+00    293.600000     13.800000
# 50%      424.000000     70.000000  6.300000e+00    302.400000     25.800000
# 75%      600.000000     86.000000  6.300000e+00    308.600000     52.800000
# max     2359.000000    100.000000  6.300000e+00    400.100000   3679.500000
#
#                type
# count  36011.000000
# mean       0.019439
# std        0.198326
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(forest.corr(),annot=True,cmap='viridis',linewidths=.5)

# %%
forest = forest.drop(['track'], axis = 1)

# %%
# Finding categorical data
print("The scan column")
print(forest['scan'].value_counts())
print()
print("The aqc_time column")
print(forest['acq_time'].value_counts())
print()
print("The satellite column")
print(forest['satellite'].value_counts())
print()
print("The instrument column")
print(forest['instrument'].value_counts())
print()
print("The version column")
print(forest['version'].value_counts())
print()
print("The daynight column")
print(forest['daynight'].value_counts())
print()
# Out:
# The scan column
# 1.0    8284
# 1.1    6000
# 1.2    3021
# 1.3    2412
# 1.4    1848
# 1.5    1610
# 1.6    1451
# 1.7    1281
# 1.8    1041
# 1.9     847
# 2.0     707
# 2.2     691
# 2.1     649
# 2.3     608
# 2.5     468
# 2.4     433
# 2.8     422
# 3.0     402
# 2.7     366
# 2.9     361
# 2.6     347
# 3.1     259
# 3.2     244
# 3.6     219
# 3.4     203
# 3.3     203
# 3.8     189
# 3.9     156
# 4.7     149
# 4.3     137
# 3.7     134
# 3.5     134
# 4.1     120
# 4.6     118
# 4.5     116
# 4.2     108
# 4.0     103
# 4.4     100
# 4.8      70
# Name: scan, dtype: int64
#
# The aqc_time column
# 506     851
# 454     631
# 122     612
# 423     574
# 448     563
#        ...
# 246       1
# 1549      1
# 1724      1
# 1629      1
# 302       1
# Name: acq_time, Length: 662, dtype: int64
#
# The satellite column
# Aqua     20541
# Terra    15470
# Name: satellite, dtype: int64
#
# The instrument column
# MODIS    36011
# Name: instrument, dtype: int64
#
# The version column
# 6.3    36011
# Name: version, dtype: int64
#
# The daynight column
# D    28203
# N     7808
# Name: daynight, dtype: int64

# %%
forest = forest.drop(['instrument', 'version'], axis = 1)

forest.head()
# Out:
#    latitude  longitude  brightness  scan    acq_date  acq_time satellite  \
# 0  -11.8070   142.0583       313.0   1.0  2019-08-01        56     Terra
# 1  -11.7924   142.0850       319.3   1.0  2019-08-01        56     Terra
# 2  -12.8398   132.8744       311.6   3.1  2019-08-01        57     Terra
# 3  -14.4306   143.3035       310.1   1.1  2019-08-01        57     Terra
# 4  -12.4953   131.4897       310.3   4.0  2019-08-01        57     Terra
#
#    confidence  bright_t31   frp daynight  type
# 0          48       297.3   6.6        D     0
# 1          71       297.3  11.3        D     0
# 2          42       298.7  23.1        D     0
# 3          33       296.1   6.5        D     0
# 4          36       298.8  27.6        D     0

# %%
daynight_map = {"D": 1, "N": 0}
satellite_map = {"Terra": 1, "Aqua": 0}

forest['daynight'] = forest['daynight'].map(daynight_map)
forest['satellite'] = forest['satellite'].map(satellite_map)

forest.head()
# Out:
#    latitude  longitude  brightness  scan    acq_date  acq_time  satellite  \
# 0  -11.8070   142.0583       313.0   1.0  2019-08-01        56          1
# 1  -11.7924   142.0850       319.3   1.0  2019-08-01        56          1
# 2  -12.8398   132.8744       311.6   3.1  2019-08-01        57          1
# 3  -14.4306   143.3035       310.1   1.1  2019-08-01        57          1
# 4  -12.4953   131.4897       310.3   4.0  2019-08-01        57          1
#
#    confidence  bright_t31   frp  daynight  type
# 0          48       297.3   6.6         1     0
# 1          71       297.3  11.3         1     0
# 2          42       298.7  23.1         1     0
# 3          33       296.1   6.5         1     0
# 4          36       298.8  27.6         1     0

# %%
# Looking at another columns type
forest['type'].value_counts()
# Out:
# 0    35666
# 2      335
# 3       10
# Name: type, dtype: int64

# %%
types = pd.get_dummies(forest['type'])
forest = pd.concat([forest, types], axis=1)

forest = forest.drop(['type'], axis = 1)
forest.head()
# Out:
#    latitude  longitude  brightness  scan    acq_date  acq_time  satellite  \
# 0  -11.8070   142.0583       313.0   1.0  2019-08-01        56          1
# 1  -11.7924   142.0850       319.3   1.0  2019-08-01        56          1
# 2  -12.8398   132.8744       311.6   3.1  2019-08-01        57          1
# 3  -14.4306   143.3035       310.1   1.1  2019-08-01        57          1
# 4  -12.4953   131.4897       310.3   4.0  2019-08-01        57          1
#
#    confidence  bright_t31   frp  daynight  0  2  3
# 0          48       297.3   6.6         1  1  0  0
# 1          71       297.3  11.3         1  1  0  0
# 2          42       298.7  23.1         1  1  0  0
# 3          33       296.1   6.5         1  1  0  0
# 4          36       298.8  27.6         1  1  0  0

# %%
# Renaming columns for better understanding

forest = forest.rename(columns={0: 'type_0', 2: 'type_2', 3: 'type_3'})

# %%
# Now I mentioned we will be converting scan column to categorical type, we will be doing this using binning method.
# Range for this columns was 1 to 4.8

bins = [0, 1, 2, 3, 4, 5]
labels = [1,2,3,4,5]
forest['scan_binned'] = pd.cut(forest['scan'], bins=bins, labels=labels)

forest.head()
# Out:
#    latitude  longitude  brightness  scan    acq_date  acq_time  satellite  \
# 0  -11.8070   142.0583       313.0   1.0  2019-08-01        56          1
# 1  -11.7924   142.0850       319.3   1.0  2019-08-01        56          1
# 2  -12.8398   132.8744       311.6   3.1  2019-08-01        57          1
# 3  -14.4306   143.3035       310.1   1.1  2019-08-01        57          1
# 4  -12.4953   131.4897       310.3   4.0  2019-08-01        57          1
#
#    confidence  bright_t31   frp  daynight  type_0  type_2  type_3 scan_binned
# 0          48       297.3   6.6         1       1       0       0           1
# 1          71       297.3  11.3         1       1       0       0           1
# 2          42       298.7  23.1         1       1       0       0           4
# 3          33       296.1   6.5         1       1       0       0           2
# 4          36       298.8  27.6         1       1       0       0           4

# %%
# Converting the datatype to datetype from string or numpy.

forest['acq_date'] = pd.to_datetime(forest['acq_date'])

# %%
# Now we will be dropping scan column and handle date type data - we can extract useful information from these datatypes 
# just like we do with categorical data.

forest = forest.drop(['scan'], axis = 1)

# %%
forest['year'] = forest['acq_date'].dt.year

forest.head()
# Out:
#    latitude  longitude  brightness   acq_date  acq_time  satellite  \
# 0  -11.8070   142.0583       313.0 2019-08-01        56          1
# 1  -11.7924   142.0850       319.3 2019-08-01        56          1
# 2  -12.8398   132.8744       311.6 2019-08-01        57          1
# 3  -14.4306   143.3035       310.1 2019-08-01        57          1
# 4  -12.4953   131.4897       310.3 2019-08-01        57          1
#
#    confidence  bright_t31   frp  daynight  type_0  type_2  type_3 scan_binned  \
# 0          48       297.3   6.6         1       1       0       0           1
# 1          71       297.3  11.3         1       1       0       0           1
# 2          42       298.7  23.1         1       1       0       0           4
# 3          33       296.1   6.5         1       1       0       0           2
# 4          36       298.8  27.6         1       1       0       0           4
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
forest['month'] = forest['acq_date'].dt.month
forest['day'] = forest['acq_date'].dt.day

# %%
forest.shape
# Out:
# (36011, 17)

# %%
# Separating our target varibale:

y = forest['confidence']
fin = forest.drop(['confidence', 'acq_date', 'acq_time', 'bright_t31', 'type_0'], axis = 1)

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(fin.corr(),annot=True,cmap='viridis',linewidths=.5)

# %%
fin.head()
# Out:
#    latitude  longitude  brightness  satellite   frp  daynight  type_2  type_3  \
# 0  -11.8070   142.0583       313.0          1   6.6         1       0       0
# 1  -11.7924   142.0850       319.3          1  11.3         1       0       0
# 2  -12.8398   132.8744       311.6          1  23.1         1       0       0
# 3  -14.4306   143.3035       310.1          1   6.5         1       0       0
# 4  -12.4953   131.4897       310.3          1  27.6         1       0       0
#
#   scan_binned  year  month  day
# 0           1  2019      8    1
# 1           1  2019      8    1
# 2           4  2019      8    1
# 3           2  2019      8    1
# 4           4  2019      8    1

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(fin.iloc[:, :500], y, test_size=0.2)

# %%
random_model = RandomForestRegressor(n_estimators=3000, random_state = 42, n_jobs = -1)

# %%
#Fit
random_model.fit(Xtrain, ytrain)

y_pred = random_model.predict(Xtest)

#Checking the accuracy
random_model_accuracy = round(random_model.score(Xtrain, ytrain)*100,2)
print(round(random_model_accuracy, 2), '%')
# Out:
# 95.34 %

# %%
#Checking the accuracy
random_model_accuracy1 = round(random_model.score(Xtest, ytest)*100,2)
print(round(random_model_accuracy1, 2), '%')
# Out:
# 66.09 %

# %%
# The accuracy is not so great, plus the model is overfitting
# So we use RandomCV

# %%
random_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 300,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
"""
n_estimators = number of trees in the foreset
max_features = max number of features considered for splitting a node
max_depth = max number of levels in each decision tree
min_samples_split = min number of data points placed in a node before the node is split
min_samples_leaf = min number of data points allowed in a leaf node
bootstrap = method for sampling data points (with or without replacement)
"""

from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 300, stop = 500, num = 20)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(15, 35, num = 7)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 3, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
                }
print(random_grid)
# Out:
# {'n_estimators': [300, 310, 321, 331, 342, 352, 363, 373, 384, 394, 405, 415, 426, 436, 447, 457, 468, 478, 489, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [15, 18, 21, 25, 28, 31, 35, None], 'min_samples_split': [2, 3, 5], 'min_samples_leaf': [1, 2, 4]}

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores

# n_iter, which controls the number of different combinations to try, and cv which is the number of folds to use for cross validation
rf_random = RandomizedSearchCV(estimator = random_model, param_distributions = random_grid, n_iter = 50, cv = 3, verbose=2, random_state=42)
# Fit the random search model
rf_random.fit(Xtrain, ytrain)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=415; total time=  31.0s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=415; total time=  27.6s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=415; total time=  38.0s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=436; total time=  41.3s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=436; total time=  39.8s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=436; total time=  34.5s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=478; total time=  13.8s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=478; total time=  13.8s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=478; total time=  15.0s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=310; total time=  19.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=310; total time=  20.4s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=310; total time=  19.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=447; total time=  35.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=447; total time=  35.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=447; total time=  38.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=457; total time=  28.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=457; total time=  28.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=457; total time=  28.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=384; total time=  29.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=384; total time=  27.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=384; total time=  27.7s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=426; total time=  30.2s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=426; total time=  30.1s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=426; total time=  31.4s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=352; total time=   9.0s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=352; total time=   9.0s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=352; total time=   9.0s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  23.8s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  23.9s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  23.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=447; total time=  11.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=447; total time=  11.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=447; total time=  11.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=373; total time=  11.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=373; total time=  10.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=373; total time=  10.8s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=384; total time=  27.6s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=384; total time=  27.9s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=384; total time=  27.8s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   6.3s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   6.3s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=300; total time=   6.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=478; total time=  34.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=478; total time=  34.5s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=478; total time=  33.0s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=  21.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=  21.6s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=  22.8s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=489; total time=  29.7s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=489; total time=  29.9s
# [CV] END max_depth=18, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=489; total time=  30.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  10.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  10.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  10.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=415; total time=   9.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=415; total time=   8.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=415; total time=   8.1s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=489; total time=  32.9s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=489; total time=  33.4s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=489; total time=  33.3s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=426; total time=  10.8s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=426; total time=  10.9s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=426; total time=  12.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=310; total time=  19.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=310; total time=  19.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=310; total time=  19.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=394; total time=  12.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=394; total time=  12.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=394; total time=  12.5s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=457; total time=  13.3s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=457; total time=  13.3s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=457; total time=  13.3s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=489; total time=  11.6s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=489; total time=  10.4s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=489; total time=  10.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=478; total time=  33.3s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=478; total time=  33.5s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=478; total time=  33.4s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=321; total time=   9.3s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=321; total time=  10.6s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=321; total time=   9.3s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=405; total time=   9.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=405; total time=   9.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=405; total time=   9.7s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=426; total time=   9.0s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=426; total time=   9.1s
# [CV] END max_depth=28, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=426; total time=   9.0s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=447; total time=  30.3s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=447; total time=  30.6s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=447; total time=  31.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=394; total time=   8.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=394; total time=   8.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=394; total time=   8.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  21.0s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  21.2s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  21.2s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  12.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  12.3s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  12.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=373; total time=  27.9s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=373; total time=  26.9s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=373; total time=  26.9s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=426; total time=  26.3s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=426; total time=  26.3s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=426; total time=  27.9s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=478; total time=  30.3s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=478; total time=  30.1s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=478; total time=  30.3s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  30.9s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  32.5s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  31.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  20.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  20.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=342; total time=  20.0s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=457; total time=  31.2s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=457; total time=  32.7s
# [CV] END max_depth=35, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=457; total time=  31.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=415; total time=  10.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=415; total time=  10.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=415; total time=  10.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=394; total time=  24.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=394; total time=  24.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=3, n_estimators=394; total time=  25.8s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  32.3s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  32.6s
# [CV] END max_depth=28, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=426; total time=  32.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=   7.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=   7.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=310; total time=   7.8s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=405; total time=  12.9s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=405; total time=  11.9s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=405; total time=  11.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=352; total time=   7.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=352; total time=   7.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=352; total time=   7.4s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=394; total time=  10.3s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=394; total time=  10.4s
# [CV] END max_depth=31, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=394; total time=  10.4s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=331; total time=  26.4s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=331; total time=  26.2s
# [CV] END max_depth=31, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=331; total time=  27.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=468; total time=   9.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=468; total time=  10.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=468; total time=  10.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=468; total time=  28.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=468; total time=  29.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=468; total time=  29.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=436; total time=  28.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=436; total time=  27.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=436; total time=  26.9s
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestRegressor(n_estimators=300, n_jobs=-1,
#                                                    random_state=42),
#                    n_iter=50,
#                    param_distributions={'max_depth': [15, 18, 21, 25, 28, 31,
#                                                       35, None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 3, 5],
#                                         'n_estimators': [300, 310, 321, 331,
#                                                          342, 352, 363, 373,
#                                                          384, 394, 405, 415,
#                                                          426, 436, 447, 457,
#                                                          468, 478, 489, 500]},
#                    random_state=42, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'max_depth': 25,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 394}

# %%
random_new = RandomForestRegressor(n_estimators = 394, min_samples_split = 2, min_samples_leaf = 1, max_features = 'sqrt',
                                      max_depth = 25, bootstrap = True)

# %%
#Fit
random_new.fit(Xtrain, ytrain)

y_pred1 = random_new.predict(Xtest)

#Checking the accuracy
random_model_accuracy1 = round(random_new.score(Xtrain, ytrain)*100,2)
print(round(random_model_accuracy1, 2), '%')
# Out:
# 95.31 %

# %%
#Checking the accuracy
random_model_accuracy2 = round(random_new.score(Xtest, ytest)*100,2)
print(round(random_model_accuracy2, 2), '%')
# Out:
# 67.77 %
